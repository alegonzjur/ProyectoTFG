# %% [markdown]
# ### Todas las librerías que vamos a utilizar.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from pathlib import Path
data_path = Path("../src")

# %% [markdown]
# ### Guardamos la lectura del fichero en una variable.

# %%
dataset = Path(data_path / "AnnualCauseDeathNumbers.csv")
data = pd.read_csv(dataset)

# %% [markdown]
# ### Ejemplo de los primeros archivos.

# %%
data.head()
# Out:
#         Entity Code  Year  Meningitis fatalities  Dementia fatalities  \
# 0  Afghanistan  AFG  1990                   2159                 1116
# 1  Afghanistan  AFG  1991                   2218                 1136
# 2  Afghanistan  AFG  1992                   2475                 1162
# 3  Afghanistan  AFG  1993                   2812                 1187
# 4  Afghanistan  AFG  1994                   3027                 1211
#
#    Parkinson fatalities  Nutritional deficiency fatalities  \
# 0                   371                               2087
# 1                   374                               2153
# 2                   378                               2441
# 3                   384                               2837
# 4                   391                               3081
#
#    Malaria fatalities  Drowning fatalities  Interpersonal violence fatalities  \
# 0                  93                 1370                               1538
# ...

# %%
rd = data.sample(frac=0.15)
rd
# Out:
#                                 Entity Code  Year  Meningitis fatalities  \
# 281                            Armenia  ARM  2001                     19
# 2181                             Gabon  GAB  2011                    106
# 1700  Eastern Mediterranean Region who   wb  2010                  39024
# 1587                          Dominica  DMA  2017                      1
# 4138                         Nicaragua  NIC  2018                     44
# ...                                ...  ...   ...                    ...
# 260                          Argentina  ARG  2010                    558
# 3889                           Morocco  MAR  2009                    818
# 5708                             Sudan  SDN  1998                   2216
# 6634            World Bank High Income   wb  1994                   7266
# 403                            Bahamas  BHS  2003                      4
#
#       Dementia fatalities  Parkinson fatalities  \
# ...

# %% [markdown]
# ### Algunas estadísticas de los archivos

# %%
rd.describe()
# Out:
#               Year  Meningitis fatalities  Dementia fatalities  \
# count  1026.000000            1026.000000         1.026000e+03
# mean   2004.601365            6653.787524         2.367635e+04
# std       8.717348           29140.630013         9.703149e+04
# min    1990.000000               0.000000         0.000000e+00
# 25%    1997.000000              16.000000         9.925000e+01
# 50%    2004.000000             125.000000         8.100000e+02
# 75%    2012.000000            1366.750000         4.248000e+03
# max    2019.000000          369377.000000         1.510447e+06
#
#        Parkinson fatalities  Nutritional deficiency fatalities  \
# count           1026.000000                        1026.000000
# mean            5536.323587                        8601.461014
# std            21963.772553                       37923.217924
# min                0.000000                           0.000000
# 25%               30.000000                          11.000000
# ...
